# %%
import pandas as pd

# %%
# reading the csv file
df_exams = pd.read_csv(r'C:\Users\Brigita\Downloads\StudentsPerformance.csv')
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             72
# 1               completed          69             90             90
# 2                    none          90             95             95
# 3                    none          47             57             57
# 4                    none          76             78             78

# %% [markdown]
# ## Adding a new column

# %% [markdown]
# #### assign()
#
# When to use assign?
#
# - Add multiple columns in a single line of code
# - When you need to over-write the values of an existing columns (best practice)
#
# It returns a new object (a copy) with all the original columns in addition to the new ones

# %%
import numpy as np

# %%
# create random numbers for our new score columns
score1 = np.random.randint(1, 100, size=1000)
score2 = np.random.randint(1, 100, size=1000)

# %%
# create a series using the random numbers
series1 = pd.Series(score1, index=np.arange(0, 1000))
series2 = pd.Series(score2, index=np.arange(0, 1000))

# %%
# using assign() method generates a new copy of the DataFrame with these additional columns included. overwrites the original variable df_exams with this updated DataFrame.
df_exams = df_exams.assign(score1=series1, score2=series2)

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    14        group B           bachelor's degree      standard
# 1    female    80        group C                some college      standard
# 2    female    28        group B             master's degree      standard
# 3      male    22        group A          associate's degree  free/reduced
# 4      male    36        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    89        group E             master's degree      standard
# 996    male    26        group C                 high school  free/reduced
# 997  female    34        group C                 high school  free/reduced
# 998  female    26        group D                some college      standard
# 999  female    14        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# 0                      none          72             72             72      14
# 1                 completed          69             90             90      80
# 2                      none          90             95             95      28
# 3                      none          47             57             57      22
# 4                      none          76             78             78      36
# ..                      ...         ...            ...            ...     ...
# 995               completed          88             99             99      89
# 996                    none          62             55             55      26
# 997               completed          59             71             71      34
# 998               completed          68             78             78      26
# 999                    none          77             86             86      14
#
#      score2
# 0        30
# 1        80
# 2        20
# 3        39
# 4        43
# ..      ...
# 995      24
# 996      33
# 997       6
# 998      78
# 999      61
#
# [1000 rows x 11 columns]

# %% [markdown]
# #### insert()
# Inserts a new column at a specific position or index.

# %%
# using insert() to add a column at a specific position
df_exams.insert(1, 'test', series1)

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female    14        group B           bachelor's degree      standard
# 1    female    80        group C                some college      standard
# 2    female    28        group B             master's degree      standard
# 3      male    22        group A          associate's degree  free/reduced
# 4      male    36        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female    89        group E             master's degree      standard
# 996    male    26        group C                 high school  free/reduced
# 997  female    34        group C                 high school  free/reduced
# 998  female    26        group D                some college      standard
# 999  female    14        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  score1  \
# 0                      none          72             72             72      14
# 1                 completed          69             90             90      80
# 2                      none          90             95             95      28
# 3                      none          47             57             57      22
# 4                      none          76             78             78      36
# ..                      ...         ...            ...            ...     ...
# 995               completed          88             99             99      89
# 996                    none          62             55             55      26
# 997               completed          59             71             71      34
# 998               completed          68             78             78      26
# 999                    none          77             86             86      14
#
#      score2
# 0        30
# 1        80
# 2        20
# 3        39
# 4        43
# ..      ...
# 995      24
# 996      33
# 997       6
# 998      78
# 999      61
#
# [1000 rows x 11 columns]
