# %%
import pandas as pd

# %%
# reading the csv file or it has to be located in the same folder where your jupyter notebook is located.
# should it be in the same directory the csv file could be read like this: df_exams = pd.read_csv('StudentsPerformance.csv')
df_exams = pd.read_csv(r'C:\Users\Brigita\Downloads\StudentsPerformance.csv')

# %%
# show first 5 rows in a dataframe
df_exams.head()
# seing summury
# df_exams
# Out:
#    gender race/ethnicity parental level of education               lunch  \
# 0       0         female                     group B   bachelor's degree
# 1       1         female                     group C        some college
# 2       2         female                     group B     master's degree
# 3       3           male                     group A  associate's degree
# 4       4           male                     group C        some college
#
#   test preparation course math score  reading score  writing score
# 0                standard       none             72             72
# 1                standard  completed             69             90
# 2                standard       none             90             95
# 3            free/reduced       none             47             57
# 4                standard       none             76             78

# %%
# show last 5 rows in a dataframe
df_exams.tail()
# Out:
#      gender race/ethnicity parental level of education            lunch  \
# 995     995         female                     group E  master's degree
# 996     996           male                     group C      high school
# 997     997         female                     group C      high school
# 998     998         female                     group D     some college
# 999     999         female                     group D     some college
#
#     test preparation course math score  reading score  writing score
# 995                standard  completed             88             99
# 996            free/reduced       none             62             55
# 997            free/reduced  completed             59             71
# 998                standard  completed             68             78
# 999            free/reduced       none             77             86

# %%
# show last n rows in a dataframe
df_exams.tail(10)
# Out:
#      gender race/ethnicity parental level of education               lunch  \
# 990     990           male                     group E         high school
# 991     991         female                     group B    some high school
# 992     992         female                     group D  associate's degree
# 993     993         female                     group D   bachelor's degree
# 994     994           male                     group A         high school
# 995     995         female                     group E     master's degree
# 996     996           male                     group C         high school
# 997     997         female                     group C         high school
# 998     998         female                     group D        some college
# 999     999         female                     group D        some college
#
#     test preparation course math score  reading score  writing score
# 990            free/reduced  completed             86             81
# ...

# %%
# getting access to the shape attribute
df_exams.shape
# Out:
# (1000, 8)

# %%
# display n rows
pd.set_option('display.max_rows', 1000)
df_exams
# Out:
#      gender race/ethnicity parental level of education               lunch  \
# 0         0         female                     group B   bachelor's degree
# 1         1         female                     group C        some college
# 2         2         female                     group B     master's degree
# 3         3           male                     group A  associate's degree
# 4         4           male                     group C        some college
# 5         5         female                     group B  associate's degree
# 6         6         female                     group B        some college
# 7         7           male                     group B        some college
# 8         8           male                     group D         high school
# 9         9         female                     group B         high school
# 10       10           male                     group C  associate's degree
# ...
