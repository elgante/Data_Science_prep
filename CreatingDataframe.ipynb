# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1 Creating a dataframe from an array

# %% [markdown]
# ### 1.1 Option 1

# %%
# creating an array 
data = np.array([[1,4],[2,5],[3,6]])

# %%
# creating a dataframe 
pd.DataFrame(data)
# Out:
#    0  1
# 0  1  4
# 1  2  5
# 2  3  6

# %%
# creating a dataframe 2, the data frame can be shown wihout df and by running ctrl+enter
df=pd.DataFrame(data, index=["row1", "row2","row3"], columns=["col1", "col2"])

# %%
# showing the dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %% [markdown]
# ### 1.2 Option 2

# %%
# creating an array with list shape
data = [[1,4],[2,5],[3,6]]

# %%
# creating a dataframe
df=pd.DataFrame(data, index=["row1", "row2","row3"], columns=["col1", "col2"])

# %%
# showing a dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %% [markdown]
# ## 2 Creating a DataFrame from a dictionary

# %%
# lists used for this example
states = ["California", "Texas", "Florida", "New York"]
population = [39613493, 29730311, 21944577, 19299981]

# %%
# storing lists within a dictionary
dict_states = {'States': states, 'Population': population}

# %%
# creating the dataframe 
df_population = pd.DataFrame(dict_states)
# df_population = pd.DataFrame.from_dict(dict_states)

# %%
# showing the dataframe
df_population
# Out:
#        States  Population
# 0  California    39613493
# 1       Texas    29730311
# 2     Florida    21944577
# 3    New York    19299981

# %% [markdown]
# ## 3 Creating a DataFrame from a csv file

# %%
# reading the csv file

df_exams = pd.read_csv(r'C:\Users\Brigita\Downloads\StudentsPerformance.csv')

# %%
# to check your current working directory
import os
print(os.getcwd())
# Out:
# C:\Users\Brigita

# %%
# show first 5 rows in a dataframe
df_exams.head()
# to see the summeury
# df_exams
# Out:
#   gender race/ethnicity parental level of education               lunch  \
# 0      0         female                     group B   bachelor's degree
# 1      1         female                     group C        some college
# 2      2         female                     group B     master's degree
# 3      3           male                     group A  associate's degree
# 4      4           male                     group C        some college
#
#   test preparation course math score reading score writing score Unnamed: 8
# 0                standard       none            72            72         74
# 1                standard  completed            69            90         88
# 2                standard       none            90            95         93
# 3            free/reduced       none            47            57         44
# 4                standard       none            76            78         75
